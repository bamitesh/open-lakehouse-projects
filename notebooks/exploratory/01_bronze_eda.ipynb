# %% [markdown]
# # Exploratory Data Analysis – Bronze Layer
#
# Use this notebook to explore raw data that has been ingested into the Bronze layer.

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName('eda-bronze').getOrCreate()
spark.sparkContext.setLogLevel('WARN')

# %%
# Load a Bronze table
# df = spark.read.format('delta').load('data/bronze/source_a')
# df.printSchema()
# df.show(20, truncate=False)
