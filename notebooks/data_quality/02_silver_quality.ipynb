# %% [markdown]
# # Data Quality Check – Silver Layer
#
# Use Great Expectations to validate Silver layer datasets.

# %%
import great_expectations as gx

context = gx.get_context()

# %%
# Example: validate that the 'id' column has no nulls
# validator = context.sources.pandas_default.read_csv('data/silver/source_a.csv')
# validator.expect_column_values_to_not_be_null('id')
# validator.validate()
